# %% [markdown]
# A. WORD ROTATION PROBLEM

# %%
def rotate_word(text):           
    #A user-defined function that moves the first character to the end, but keeping the other remaining characters at place. Capitalization is also preserved.
 
    return text[1:] + text[0]    
        #text[1:] is block of code that slices the characters of the string from the index position 1 all the way to the end
        #text[0] gets the character from the index position zero
        # the two is combined by "+" that will put character of index position zero at last without changing others' position
        #the output is then returned
    
print(rotate_word("Python"))      
    #when a certain text is placed, the function is called, and the output will be printed
# Out:
# ythonP

# %% [markdown]
# B. USERNAME BUILDER PROBLEM

# %%
def make_username(first_name, last_name):
    #a user-defined function that accepts two string values, first name and last name, respectively

    lowercase_first = first_name.lower()
        #converts the first name in lowercase

    final_first = lowercase_first.replace(" ","")
        #removes any spaces found in the lowercased first name
    
    lowercase_last = last_name.lower()
        #converts the last name in lowercase

    final_last = lowercase_last.replace(" ","")
        #removes any spaces found in the lowercased last name
    
    return final_first + "." + final_last
#returns an output where the two final strings are added together, while also putting a period in the center


print(make_username("Leigh","Aldrie")) 
    #two strings will come from the user, the function is then called, and the output is printed
# Out:
# leigh.aldrie

# %% [markdown]
# C. BOOKEND SWAP PROBLEM

# %%
def swap_bookends(items):
    #creates a user-defined function, the items is an input passed in the function, which is expected to be a list containing at least two elements.
    
    first, *middle, last = items 
        # "first" takes the first element in "items" list and stores it in the variable
        # "*middle" possessing an asterisk to capture all the remaining elements in between the first and last elements of the "items" list, grouping it in a new list
        # "last" takes the last element in "items" list and stores it in the variable
    
    return [last] + middle + [first]
        #[last] wraps the single last elemento to be a list
        # middle joins both the "last" and the "first" list.
        #[first] wraps the single first element to be a list
        # the newly constructed list is then returned

swap_bookends([1, 2, 3, 4, 5])
    #function is called, and the output will create a new list with reversed first and last elements.
# Out:
# [5, 2, 3, 4, 1]
